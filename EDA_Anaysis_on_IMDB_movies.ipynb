# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
#Read the csv file stored in the local directory
movies = pd.read_csv("C:/Users/shem/Downloads/Movie+Assignment+Data.csv")
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here
print(movies.shape)
print(movies.columns)
# Out:
# (5043, 28)
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here
print(movies.isnull().sum())
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# Write your code for row-wise null count here
print(movies.isnull().sum(axis =1))
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
# Write your code for column-wise null percentages here
print(round(100*(movies.isnull().sum()/len(movies.index)),2))
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.24
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# ...

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 
movies =movies.drop('color', axis = 1)
movies =movies.drop('director_facebook_likes', axis = 1)
movies =movies.drop('actor_1_facebook_likes', axis = 1)
movies =movies.drop('actor_2_facebook_likes', axis = 1)
movies =movies.drop('actor_3_facebook_likes', axis = 1)
movies =movies.drop('actor_2_name', axis = 1)
movies =movies.drop('cast_total_facebook_likes', axis = 1)
movies =movies.drop('actor_3_name', axis = 1)
movies =movies.drop('duration', axis = 1)
movies =movies.drop('content_rating', axis = 1)
movies =movies.drop('country', axis = 1)
movies =movies.drop('movie_imdb_link', axis = 1)
movies =movies.drop('aspect_ratio', axis = 1)
movies =movies.drop('plot_keywords', axis = 1)

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# Write your code for dropping the rows here
total_len = len(movies.index)
cols = movies.columns[100*(movies.isnull().sum()/len(movies.index))>5]
movies= movies.dropna(subset = cols)
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %% [markdown]
# -  ### Subtask 2.4: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here
#Filling the NAN values with English for language column
movies.loc[(movies['language'].isnull())] = 'English'

# %% [markdown]
# -  ### Subtask 2.5: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# Write your code for checking number of retained rows here
print(len(movies.index))
print(100 * (len(movies.index)/total_len))
# Out:
# 3891
# 77.15645449137418

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Write your code for unit conversion here
#Converting the budget column to millions by dividing with 1e6
millions_bd = pd.to_numeric(movies['budget'], errors='coerce')/1e6
movies['budget']  = millions_bd.round(3)
print(movies['budget'])
#Converting the gross column to millions by dividing with 1e6
millions_gr = pd.to_numeric(movies['gross'], errors='coerce')/1e6
movies['gross']  = millions_gr.round(3)
print(movies['gross'])
# Out:
# 0       237.000
# 1       300.000
# 2       245.000
# 3       250.000
# 5       263.700
#          ...
# 5033      0.007
# 5034      0.007
# 5035      0.007
# 5037      0.009
# 5042      0.001
# Name: budget, Length: 3891, dtype: float64
# 0       760.506
# 1       309.404
# 2       200.074
# 3       448.131
# 5        73.059
#          ...
# 5033      0.425
# 5034      0.070
# 5035      2.041
# 5037      0.005
# 5042      0.085
# Name: gross, Length: 3891, dtype: float64

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Plot `profit` (y-axis) vs `budget` (x- axis) and observe the outliers using the appropriate chart type.
#     4. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here
#Creating profit column by subtracting gross from budget
movies['profit'] = movies['gross'] - movies['budget']
movies['profit']
# Out:
# 0       523.506
# 1         9.404
# 2       -44.926
# 3       198.131
# 5      -190.641
#          ...
# 5033      0.418
# 5034      0.063
# 5035      2.034
# 5037     -0.004
# 5042      0.084
# Name: profit, Length: 3891, dtype: float64

# %%
# Write your code for sorting the dataframe here
movies = movies.sort_values(by=['profit'])
movies
# Out:
#         director_name num_critic_for_reviews    gross  \
# 2988     Joon-ho Bong                    363    2.201
# 3859   Chan-wook Park                    202    0.212
# 3005     Lajos Koltai                     73    0.196
# 2323   Hayao Miyazaki                    174    2.298
# 2334  Katsuhiro Ôtomo                    105    0.410
# ...               ...                    ...      ...
# 29    Colin Trevorrow                    644  652.177
# 0       James Cameron                    723  760.506
# 3086          English                English      NaN
# 4110          English                English      NaN
# 4958          English                English      NaN
#
#                                                  genres         actor_1_name  \
# 2988                         Comedy|Drama|Horror|Sci-Fi            Doona Bae
# 3859                                        Crime|Drama         Min-sik Choi
# 3005                                  Drama|Romance|War         Marcell Nagy
# ...

# %%
# Write code for profit vs budget plot here
#Plots
import seaborn as sns
import matplotlib.pyplot as plt
#Creating a joint plot to show budget vs profit
sns.jointplot('profit', 'budget', movies)
#Code to show the plot
plt.show()

# %%
top10 = movies.nlargest(10, ['profit']) 
top10
# Write your code to get the top 10 profiting movies here
# Out:
#           director_name num_critic_for_reviews    gross  \
# 0         James Cameron                    723  760.506
# 29      Colin Trevorrow                    644  652.177
# 26        James Cameron                    315  658.672
# 3024       George Lucas                    282  460.936
# 3080   Steven Spielberg                    215  434.949
# 794         Joss Whedon                    703  623.280
# 17          Joss Whedon                    703  623.280
# 509        Roger Allers                    186  422.784
# 240        George Lucas                    320  474.545
# 66    Christopher Nolan                    645  533.316
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# 3024           Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# ...

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have noticed a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`. Note that the same `movie_title` can be there in different languages.

# %%
# Write your code for dropping duplicate values here
#print(top10)
top10 = top10.drop_duplicates(['movie_title','language'])
top10
# Out:
#           director_name num_critic_for_reviews    gross  \
# 0         James Cameron                    723  760.506
# 29      Colin Trevorrow                    644  652.177
# 26        James Cameron                    315  658.672
# 3024       George Lucas                    282  460.936
# 3080   Steven Spielberg                    215  434.949
# 794         Joss Whedon                    703  623.280
# 509        Roger Allers                    186  422.784
# 240        George Lucas                    320  474.545
# 66    Christopher Nolan                    645  533.316
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# 3024           Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# ...

# %%
# Write code for repeating subtask 2 here
#Sort by profit and show the joint plot for the new dataframe
top10 = top10.sort_values(by=['profit'])
print(top10)
sns.jointplot('profit', 'budget', top10)
#sns.boxplot(x = movies['budget'],y= movies['profit'])
plt.show()
# Out:
#           director_name num_critic_for_reviews    gross  \
# 66    Christopher Nolan                    645  533.316
# 240        George Lucas                    320  474.545
# 509        Roger Allers                    186  422.784
# 794         Joss Whedon                    703  623.280
# 3080   Steven Spielberg                    215  434.949
# 3024       George Lucas                    282  460.936
# 26        James Cameron                    315  658.672
# 29      Colin Trevorrow                    644  652.177
# 0         James Cameron                    723  760.506
#
#                                         genres         actor_1_name  \
# 66                 Action|Crime|Drama|Thriller       Christian Bale
# 240            Action|Adventure|Fantasy|Sci-Fi      Natalie Portman
# 509   Adventure|Animation|Drama|Family|Musical    Matthew Broderick
# 794                    Action|Adventure|Sci-Fi      Chris Hemsworth
# ...

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'
 #Creating a new data frame df by eliminating the null values from movies
df = movies.dropna(how= 'any')
#Converting the num_voted_users to integer
df['num_voted_users'] =  df['num_voted_users'].astype(int)
#Selecting only the num_voted_users > 25000 and store in a new dataframe as rslt_df
rslt_df = df[df['num_voted_users'] > 25000] 
#Converting the imdb_score to str
rslt_df['imdb_score'] =  rslt_df['imdb_score'].astype(str)
#Get the top 250 entries with highest imdb_score
IMDb_Top_250 = rslt_df.sort_values(by=['imdb_score'],ascending = False,inplace= False).head(250)
#Creating a rank column based on the imdb_score 
IMDb_Top_250['Rank'] = IMDb_Top_250['imdb_score'].rank() 
IMDb_Top_250
# Out:
#              director_name num_critic_for_reviews    gross  \
# 1937        Frank Darabont                    199   28.341
# 3466  Francis Ford Coppola                    208  134.822
# 66       Christopher Nolan                    645  533.316
# 2837  Francis Ford Coppola                    149   57.300
# 4498          Sergio Leone                    181    6.100
# ...                    ...                    ...      ...
# 75              Doug Liman                    585  100.190
# 927         Andrew Adamson                    212  267.652
# 69             Jon Favreau                    486  318.298
# 4640       Cristian Mungiu                    233    1.186
# 1871          Pierre Morel                    309  145.001
#
#                                          genres       actor_1_name  \
# 1937                                Crime|Drama     Morgan Freeman
# 3466                                Crime|Drama          Al Pacino
# ...

# %%
# Write your code to extract top foreign language films from 'IMDb_Top_250' here

#From the new df- IMDb_Top_250 get the non englist films
Top_Foreign_Lang_Film = IMDb_Top_250[IMDb_Top_250['language']!= 'English']
Top_Foreign_Lang_Film
# Out:
#                          director_name num_critic_for_reviews   gross  \
# 4498                      Sergio Leone                    181   6.100
# 4747                    Akira Kurosawa                    153   0.269
# 4029                Fernando Meirelles                    214   7.563
# 2373                    Hayao Miyazaki                    246  10.050
# 4921                      Majid Majidi                     46   0.925
# 4259  Florian Henckel von Donnersmarck                    215  11.285
# 1298                Jean-Pierre Jeunet                    242  33.202
# 4105                    Chan-wook Park                    305   2.181
# 2970                 Wolfgang Petersen                     96  11.433
# 2323                    Hayao Miyazaki                    174   2.298
# 1329                    S.S. Rajamouli                     44   6.498
# 4659                    Asghar Farhadi                    354   7.098
# ...

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.  Incase of a tie in IMDb score between two directors, sort them alphabetically.

# %%
# Write your code for extracting the top 10 directors here
#First convert the imdb_score to float
df['imdb_score'] =  df['imdb_score'].astype(float)
#Group the data based on director_name  and show the mean of imdb_score
new_df = df.groupby('director_name')[['imdb_score']].mean()
#Get the top 10 directors by sorting on imdb_score  in descending order and also if the scores are same then sort by director name 
top10director = new_df.sort_values(by = ['imdb_score','director_name'],ascending = (False,True)).head(10)
top10director
# Out:
#                        imdb_score
# director_name
# Charles Chaplin          8.600000
# Tony Kaye                8.600000
# Alfred Hitchcock         8.500000
# Damien Chazelle          8.500000
# Majid Majidi             8.500000
# Ron Fricke               8.500000
# Sergio Leone             8.433333
# Christopher Nolan        8.425000
# Asghar Farhadi           8.400000
# Marius A. Markevicius    8.400000

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here
#movies['genre_1'] = movies['genres']
#Creating new columns genre1 and genre2 by splitting genres 
movies['genre_1'] = movies['genres'].str.split('|').str[0]
movies['genre_2'] = movies['genres'].str.split('|').str[1]
#If genre2 is empty,copy genre1 into it
movies['genre_2'].fillna(movies['genre_1'], inplace = True)

# %%
#Grouping by genre_1,genre2 and showing the mean of gross
movies_by_segment =movies.groupby(['genre_1','genre_2'])[['gross']].mean()
movies_by_segment
# Out:
#                          gross
# genre_1  genre_2
# Action   Action      59.521000
#          Adventure  110.382532
#          Animation   92.680625
#          Biography   44.355500
#          Comedy      53.038160
# ...                        ...
# Romance  Sci-Fi      62.453000
# Sci-Fi   Sci-Fi       0.018000
#          Thriller    29.793857
# Thriller Thriller     0.040333
# Western  Western     15.914667
#
# [104 rows x 1 columns]

# %%
#PopGenre =  movies_by_segment.group
#Sort the movies_by_segment to get5  most popular genre based on gross
PopGenre = movies_by_segment.sort_values(by=['gross'],ascending = False).head(5)
PopGenre
# Out:
#                           gross
# genre_1   genre_2
# Family    Sci-Fi     434.949000
# Adventure Sci-Fi     228.627875
#           Animation  116.998573
#           Family     116.520971
# Action    Adventure  110.382532

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_users_for_review` and identify the actors which have the highest mean.
#     5. Observe the change in number of voted users over decades using a bar chart. Create a column called `decade` which represents the decade to which every movie belongs to. For example, the  `title_year`  year 1923, 1925 should be stored as 1920s. Sort the dataframe based on the column `decade`, group it by `decade` and find the sum of users voted in each decade. Store this in a new data frame called `df_by_decade`.

# %%
# Write your code for creating three new dataframes here

Meryl_Streep = movies[movies['actor_1_name']== 'Meryl Streep']
Meryl_Streep
# Out:
#        director_name num_critic_for_reviews    gross  \
# 1483  Robert Redford                    227   14.998
# 1674   Carl Franklin                     64   23.209
# 1106   Curtis Hanson                     42   46.816
# 3135   Robert Altman                    211   20.339
# 1925  Stephen Daldry                    174   41.598
# 2781  Phyllida Lloyd                    331   29.959
# 410     Nancy Meyers                    187  112.703
# 1618   David Frankel                    234   63.536
# 1204     Nora Ephron                    252   94.125
# 1575  Sydney Pollack                     66   87.100
# 1408   David Frankel                    208  124.733
#
#                                genres  actor_1_name  \
# 1483               Drama|Thriller|War  Meryl Streep
# 1674                            Drama  Meryl Streep
# 1106  Action|Adventure|Crime|Thriller  Meryl Streep
# 3135               Comedy|Drama|Music  Meryl Streep
# 1925                    Drama|Romance  Meryl Streep
# ...

# %%
Leo_Caprio = movies[movies['actor_1_name']== 'Leonardo DiCaprio']
Leo_Caprio
# Out:
#               director_name num_critic_for_reviews    gross  \
# 307            Edward Zwick                    166   57.366
# 641            Ridley Scott                    238   39.380
# 326         Martin Scorsese                    233   77.680
# 1560              Sam Raimi                     63   18.637
# 1114             Sam Mendes                    323   22.878
# 990             Danny Boyle                    118   39.779
# 2067             Jerry Zaks                     45   12.783
# 257         Martin Scorsese                    267  102.609
# 1453         Clint Eastwood                    392   37.305
# 308         Martin Scorsese                    606  116.867
# 1422        Randall Wallace                     83   56.876
# 2757           Baz Luhrmann                    106   46.339
# 50             Baz Luhrmann                    490  144.813
# 3476           Baz Luhrmann                    490  144.813
# 361         Martin Scorsese                    352  132.373
# ...

# %%
Brad_Pitt = movies[movies['actor_1_name']== 'Brad Pitt']
Brad_Pitt
# Out:
#               director_name num_critic_for_reviews    gross  \
# 382              Tony Scott                    142    0.027
# 147       Wolfgang Petersen                    220  133.228
# 792         Patrick Gilmore                     98   26.288
# 611     Jean-Jacques Annaud                     76   37.902
# 1722         Andrew Dominik                    273    3.905
# 683           David Fincher                    315   37.023
# 101           David Fincher                    362  127.491
# 1490        Terrence Malick                    584   13.303
# 2333    Angelina Jolie Pitt                    131    0.531
# 2898             Tony Scott                    122   12.282
# 2682         Andrew Dominik                    414   14.939
# 2204  Alejandro G. Iñárritu                    285   34.301
# 254       Steven Soderbergh                    198  125.532
# 470              David Ayer                    406   85.707
# 940             Neil Jordan                    120  105.265
# ...

# %%
# Write your code for combining the three dataframes here
comb = [Meryl_Streep,Leo_Caprio,Brad_Pitt]
#Combining the 3 dataframes using concat function
Combined = pd.concat(comb)
Combined
# Out:
#               director_name num_critic_for_reviews    gross  \
# 1483         Robert Redford                    227   14.998
# 1674          Carl Franklin                     64   23.209
# 1106          Curtis Hanson                     42   46.816
# 3135          Robert Altman                    211   20.339
# 1925         Stephen Daldry                    174   41.598
# 2781         Phyllida Lloyd                    331   29.959
# 410            Nancy Meyers                    187  112.703
# 1618          David Frankel                    234   63.536
# 1204            Nora Ephron                    252   94.125
# 1575         Sydney Pollack                     66   87.100
# 1408          David Frankel                    208  124.733
# 307            Edward Zwick                    166   57.366
# 641            Ridley Scott                    238   39.380
# 326         Martin Scorsese                    233   77.680
# 1560              Sam Raimi                     63   18.637
# ...

# %%
# Write your code for grouping the combined dataframe here
#Converting the num_critic_for_reviews and num_user_for_reviews to int
Combined['num_critic_for_reviews'] = Combined['num_critic_for_reviews'].astype(int)
#Group by actor_1_name and show the mean of num_critic_for_reviews
new_comb = Combined.groupby('actor_1_name')[['num_critic_for_reviews']].mean()
#Sort in descending order based on mean of num_critic_for_reviews
new_comb.sort_values(by=['num_critic_for_reviews'],ascending = False)
# Out:
#                    num_critic_for_reviews
# actor_1_name
# Leonardo DiCaprio              330.190476
# Brad Pitt                      245.000000
# Meryl Streep                   181.454545

# %%
# Write the code for finding the mean of critic reviews and audience reviews here
#Converting the num_user_for_reviews and num_user_for_reviews to int
Combined['num_user_for_reviews'] = Combined['num_user_for_reviews'].astype(int)
new_comb = Combined.groupby('actor_1_name')[['num_user_for_reviews']].mean()
new_comb.sort_values(by=['num_user_for_reviews'],ascending = False)
# Out:
#                    num_user_for_reviews
# actor_1_name
# Leonardo DiCaprio            914.476190
# Brad Pitt                    742.352941
# Meryl Streep                 297.181818

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!

# %%
# Write the code for calculating decade here
import numpy as np
movies = movies.dropna(how= 'any')
#Code to calculate the new column decade from title_year by converting the values to corresponding decade
movies['decade'] = (movies['title_year']//10)*10
movies['decade']
# Out:
# 2988    2000
# 3859    2000
# 3005    2000
# 2323    1990
# 2334    2000
#         ...
# 3080    1980
# 3024    1970
# 26      1990
# 29      2010
# 0       2000
# Name: decade, Length: 3878, dtype: object

# %%
# Write your code for creating the data frame df_by_decade here 
movies['num_voted_users'] = pd.to_numeric(movies['num_voted_users'], errors='coerce')
df_by_decade  = movies.groupby('decade',as_index = False)[['num_voted_users']].sum(level=int)
df_by_decade['decade'] = pd.to_datetime(df_by_decade['decade'],format='%Y')
df_by_decade['decade'] = df_by_decade['decade'].map(lambda x: x.year)
df_by_decade
# Out:
#    decade  num_voted_users
# 0    1920           116387
# 1    1930           804839
# 2    1940           230838
# 3    1950           678336
# 4    1960          2983442
# 5    1970          8681959
# 6    1980         20091781
# 7    1990         70088770
# 8    2000        173023123
# 9    2010        121591640

# %%
# Write your code for plotting number of voted users vs decade
import numpy
sns.barplot(x='decade', y='num_voted_users', data=df_by_decade,orient='v')
plt.show()
